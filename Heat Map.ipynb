# %%
#Create a simple heatmap using random numbers
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
data = np.random.rand(10, 12)

# Create a heatmap
sns.heatmap(data)

# Display the plot
plt.show()
